# %%
import pandas as pd
import os

# ── Configuration ─────────────────────────────────────────────────────────────
INPUT_FILE = "MUP_DPR_RY25_P04_V10_DY23_NPIBN.csv"
OUTPUT_FILE = "pharmaguard_sample.csv"
SAMPLE_SIZE = 200000

# ── Loading ───────────────────────────────────────────────────────────────────
print("Loading dataset... (this may take 1-2 minutes)")
df = pd.read_csv(INPUT_FILE, low_memory=False)
print(f"Dataset loaded: {len(df):,} rows, {len(df.columns)} columns")
print(f"\nAvailable columns:\n{list(df.columns)}")

# ── Stratified sampling ───────────────────────────────────────────────────────
print(f"\nExtracting stratified sample of {SAMPLE_SIZE:,} rows...")

if 'Prscrbr_State_Abrvtn' in df.columns:
    sample = df.groupby('Prscrbr_State_Abrvtn', group_keys=False).apply(
        lambda x: x.sample(min(len(x), int(SAMPLE_SIZE * len(x) / len(df))))
    )
    sample = sample.sample(min(SAMPLE_SIZE, len(sample)), random_state=42)
else:
    sample = df.sample(n=min(SAMPLE_SIZE, len(df)), random_state=42)

print(f"Sample extracted: {len(sample):,} rows")

# ── Save ──────────────────────────────────────────────────────────────────────
sample.to_csv(OUTPUT_FILE, index=False)
size_mb = os.path.getsize(OUTPUT_FILE) / (1024 * 1024)
print(f"\nFile saved: {OUTPUT_FILE} ({size_mb:.1f} MB)")
print("Ready for the prototype!")
# Out:
# Loading dataset... (this may take 1-2 minutes)
# Dataset loaded: 26,794,878 rows, 22 columns
#
# Available columns:
# ['Prscrbr_NPI', 'Prscrbr_Last_Org_Name', 'Prscrbr_First_Name', 'Prscrbr_City', 'Prscrbr_State_Abrvtn', 'Prscrbr_State_FIPS', 'Prscrbr_Type', 'Prscrbr_Type_Src', 'Brnd_Name', 'Gnrc_Name', 'Tot_Clms', 'Tot_30day_Fills', 'Tot_Day_Suply', 'Tot_Drug_Cst', 'Tot_Benes', 'GE65_Sprsn_Flag', 'GE65_Tot_Clms', 'GE65_Tot_30day_Fills', 'GE65_Tot_Drug_Cst', 'GE65_Tot_Day_Suply', 'GE65_Bene_Sprsn_Flag', 'GE65_Tot_Benes']
#
# Extracting stratified sample of 200,000 rows...
# C:\Users\capsi\AppData\Local\Temp\ipykernel_15248\645964663.py:19: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sample = df.groupby('Prscrbr_State_Abrvtn', group_keys=False).apply(
# Sample extracted: 199,972 rows
#
# File saved: pharmaguard_sample.csv (28.9 MB)
# Ready for the prototype!
